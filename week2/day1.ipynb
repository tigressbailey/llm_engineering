# %% [markdown]
# # Welcome to Week 2!
#
# ## Frontier Model APIs
#
# In Week 1, we used multiple Frontier LLMs through their Chat UI, and we connected with the OpenAI's API.
#
# Today we'll connect with them through their APIs..

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Important Note - Please read me</h2>
#             <span style="color:#900;">I'm continually improving these labs, adding more examples and exercises.
#             At the start of each week, it's worth checking you have the latest code.<br/>
#             First do a git pull and merge your changes as needed</a>. Check out the GitHub guide for instructions. Any problems? Try asking ChatGPT to clarify how to merge - or contact me!<br/>
#             </span>
#         </td>
#     </tr>
# </table>
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/resources.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#f71;">Reminder about the resources page</h2>
#             <span style="color:#f71;">Here's a link to resources for the course. This includes links to all the slides.<br/>
#             <a href="https://edwarddonner.com/2024/11/13/llm-engineering-resources/">https://edwarddonner.com/2024/11/13/llm-engineering-resources/</a><br/>
#             Please keep this bookmarked, and I'll continue to add more useful links there over time.
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ## Setting up your keys - OPTIONAL!
#
# We're now going to try asking a bunch of models some questions!
#
# This is totally optional. If you have keys to Anthropic, Gemini or others, then you can add them in.
#
# If you'd rather not spend the extra, then just watch me do it!
#
# For OpenAI, visit https://openai.com/api/
# For Anthropic, visit https://console.anthropic.com/
# For Google, visit https://aistudio.google.com/
# For DeepSeek, visit https://platform.deepseek.com/
# For Groq, visit https://console.groq.com/
# For Grok, visit https://console.x.ai/
#
#
# You can also use OpenRouter as your one-stop-shop for many of these! OpenRouter is "the unified interface for LLMs":
#
# For OpenRouter, visit https://openrouter.ai/
#
#
# With each of the above, you typically have to navigate to:
# 1. Their billing page to add the minimum top-up (except Gemini, Groq, Google, OpenRouter may have free tiers)
# 2. Their API key page to collect your API key
#
# ### Adding API keys to your .env file
#
# When you get your API keys, you need to set them as environment variables by adding them to your `.env` file.
#
# ```
# OPENAI_API_KEY=xxxx
# ANTHROPIC_API_KEY=xxxx
# GOOGLE_API_KEY=xxxx
# DEEPSEEK_API_KEY=xxxx
# GROQ_API_KEY=xxxx
# GROK_API_KEY=xxxx
# OPENROUTER_API_KEY=xxxx
# ```
#
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Any time you change your .env file</h2>
#             <span style="color:#900;">Remember to Save it! And also rerun load_dotenv(override=True)<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# imports

import os
import requests
from dotenv import load_dotenv
from openai import OpenAI
from IPython.display import Markdown, display

# %%
load_dotenv(override=True)
openai_api_key = os.getenv('OPENAI_API_KEY')
anthropic_api_key = os.getenv('ANTHROPIC_API_KEY')
google_api_key = os.getenv('GOOGLE_API_KEY')
deepseek_api_key = os.getenv('DEEPSEEK_API_KEY')
groq_api_key = os.getenv('GROQ_API_KEY')
grok_api_key = os.getenv('GROK_API_KEY')
openrouter_api_key = os.getenv('OPENROUTER_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set")
    
if anthropic_api_key:
    print(f"Anthropic API Key exists and begins {anthropic_api_key[:7]}")
else:
    print("Anthropic API Key not set (and this is optional)")

if google_api_key:
    print(f"Google API Key exists and begins {google_api_key[:2]}")
else:
    print("Google API Key not set (and this is optional)")

if deepseek_api_key:
    print(f"DeepSeek API Key exists and begins {deepseek_api_key[:3]}")
else:
    print("DeepSeek API Key not set (and this is optional)")

if groq_api_key:
    print(f"Groq API Key exists and begins {groq_api_key[:4]}")
else:
    print("Groq API Key not set (and this is optional)")

if grok_api_key:
    print(f"Grok API Key exists and begins {grok_api_key[:4]}")
else:
    print("Grok API Key not set (and this is optional)")

if openrouter_api_key:
    print(f"OpenRouter API Key exists and begins {openrouter_api_key[:3]}")
else:
    print("OpenRouter API Key not set (and this is optional)")
# Out:
# OpenAI API Key exists and begins sk-proj-
# Anthropic API Key exists and begins xxxx
# Google API Key exists and begins AI
# DeepSeek API Key exists and begins xxx
# Groq API Key exists and begins xxxx
# Grok API Key exists and begins xxxx
# OpenRouter API Key exists and begins xxx

# %%
# Connect to OpenAI client library
# A thin wrapper around calls to HTTP endpoints

openai = OpenAI()

# For Gemini, DeepSeek and Groq, we can use the OpenAI python client
# Because Google and DeepSeek have endpoints compatible with OpenAI
# And OpenAI allows you to change the base_url

anthropic_url = "https://api.anthropic.com/v1/"
gemini_url = "https://generativelanguage.googleapis.com/v1beta/openai/"
deepseek_url = "https://api.deepseek.com"
groq_url = "https://api.groq.com/openai/v1"
grok_url = "https://api.x.ai/v1"
openrouter_url = "https://openrouter.ai/api/v1"
ollama_url = "http://localhost:11434/v1"

anthropic = OpenAI(api_key=anthropic_api_key, base_url=anthropic_url)
gemini = OpenAI(api_key=google_api_key, base_url=gemini_url)
deepseek = OpenAI(api_key=deepseek_api_key, base_url=deepseek_url)
groq = OpenAI(api_key=groq_api_key, base_url=groq_url)
grok = OpenAI(api_key=grok_api_key, base_url=grok_url)
openrouter = OpenAI(base_url=openrouter_url, api_key=openrouter_api_key)
ollama = OpenAI(api_key="ollama", base_url=ollama_url)

# %%
tell_a_joke = [
    {"role": "user", "content": "Tell a joke for a student on the journey to becoming an expert in LLM Engineering"},
]

# %%
response = openai.chat.completions.create(model="gpt-4.1-mini", messages=tell_a_joke)
display(Markdown(response.choices[0].message.content))
# Out:
# Sure! Here’s a joke for an aspiring LLM engineer:
#
# Why did the language model break up with the dataset?
#
# Because it found too many *unsupported tokens* in the relationship!

# %%
response = ollama.chat.completions.create(model="deepseek-r1:1.5b", messages=tell_a_joke)
display(Markdown(response.choices[0].message.content))
# Out:
# A classic joke about becoming an expert in LLM Engineering:
#
# Why did the student get distracted trying to learn LLMs?
# Because their troublehouse was getting too busy with other stuff.
#
# Then, after hours of frustration...
# They won the LLM challenge!

# %% [markdown]
# ## Training vs Inference time scaling

# %%
easy_puzzle = [
    {"role": "user", "content": 
        "You toss 2 coins. One of them is heads. What's the probability the other is tails? Answer with the probability only."},
]

# %%
response = openai.chat.completions.create(model="gpt-5-nano", messages=easy_puzzle, reasoning_effort="minimal")
display(Markdown(response.choices[0].message.content))
# Out:
# 1/2

# %%
response = openai.chat.completions.create(model="gpt-5-nano", messages=easy_puzzle, reasoning_effort="low")
display(Markdown(response.choices[0].message.content))
# Out:
# 2/3

# %%
response = openai.chat.completions.create(model="gpt-5-mini", messages=easy_puzzle, reasoning_effort="minimal")
display(Markdown(response.choices[0].message.content))
# Out:
# 2/3

# %% [markdown]
# ## Testing out the best models on the planet

# %%
hard = """
On a bookshelf, two volumes of Pushkin stand side by side: the first and the second.
The pages of each volume together have a thickness of 2 cm, and each cover is 2 mm thick.
A worm gnawed (perpendicular to the pages) from the first page of the first volume to the last page of the second volume.
What distance did it gnaw through?
"""
hard_puzzle = [
    {"role": "user", "content": hard}
]

# %%
response = openai.chat.completions.create(model="gpt-5-nano", messages=hard_puzzle, reasoning_effort="minimal")
display(Markdown(response.choices[0].message.content))

# %%
response = anthropic.chat.completions.create(model="claude-sonnet-4-5-20250929", messages=hard_puzzle)
display(Markdown(response.choices[0].message.content))

# %%
response = openai.chat.completions.create(model="gpt-5", messages=hard_puzzle)
display(Markdown(response.choices[0].message.content))

# %%
response = gemini.chat.completions.create(model="gemini-2.5-pro", messages=hard_puzzle)
display(Markdown(response.choices[0].message.content))

# %% [markdown]
# ## A spicy challenge to test the competitive spirit

# %%
dilemma_prompt = """
You and a partner are contestants on a game show. You're each taken to separate rooms and given a choice:
Cooperate: Choose "Share" — if both of you choose this, you each win $1,000.
Defect: Choose "Steal" — if one steals and the other shares, the stealer gets $2,000 and the sharer gets nothing.
If both steal, you both get nothing.
Do you choose to Steal or Share? Pick one.
"""

dilemma = [
    {"role": "user", "content": dilemma_prompt},
]

# %%
response = anthropic.chat.completions.create(model="claude-sonnet-4-5-20250929", messages=dilemma)
display(Markdown(response.choices[0].message.content))

# %%
response = groq.chat.completions.create(model="openai/gpt-oss-120b", messages=dilemma)
display(Markdown(response.choices[0].message.content))

# %%
response = deepseek.chat.completions.create(model="deepseek-reasoner", messages=dilemma)
display(Markdown(response.choices[0].message.content))

# %%
response = grok.chat.completions.create(model="grok-4", messages=dilemma)
display(Markdown(response.choices[0].message.content))

# %% [markdown]
# ## Going local
#
# Just use the OpenAI library pointed to localhost:11434/v1

# %%
requests.get("http://localhost:11434/").content

# If not running, run ollama serve at a command line
# Out:
# b'Ollama is running'

# %%
# !ollama pull llama3.2

# %%
# Only do this if you have a large machine - at least 16GB RAM

# !ollama pull gpt-oss:20b

# %%
response = ollama.chat.completions.create(model="llama3.2:1b", messages=easy_puzzle)
display(Markdown(response.choices[0].message.content))
# Out:
# Since we know one coin is heads and one is tails, the only possibility for the second coin to be tails is if it lands on the other side that has already landed tails. Therefore, out of 4 possible outcomes (HH, HT, TH, TT), two are favorable (TT). Thus, the probability of the other coin landing on tails is 2/4 or 1/2.

# %%
response = ollama.chat.completions.create(model="gpt-oss:20b", messages=easy_puzzle)
display(Markdown(response.choices[0].message.content))

# %% [markdown]
# ## Gemini and Anthropic Client Library
#
# We're going via the OpenAI Python Client Library, but the other providers have their libraries too

# %%
from google import genai

client = genai.Client()

response = client.models.generate_content(
    model="gemini-2.5-flash-lite", contents="Describe the color Blue to someone who's never been able to see in 1 sentence"
)
print(response.text)

# %%
from anthropic import Anthropic

client = Anthropic()

response = client.messages.create(
    model="claude-sonnet-4-5-20250929",
    messages=[{"role": "user", "content": "Describe the color Blue to someone who's never been able to see in 1 sentence"}],
    max_tokens=100
)
print(response.content[0].text)

# %% [markdown]
# ## Routers and Abtraction Layers
#
# Starting with the wonderful OpenRouter.ai - it can connect to all the models above!
#
# Visit openrouter.ai and browse the models.
#
# Here's one we haven't seen yet: GLM 4.5 from Chinese startup z.ai

# %%
response = openrouter.chat.completions.create(model="z-ai/glm-4.5", messages=tell_a_joke)
display(Markdown(response.choices[0].message.content))

# %% [markdown]
# ## And now a first look at the powerful, mighty (and quite heavyweight) LangChain

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(model="gpt-5-mini")
response = llm.invoke(tell_a_joke)

display(Markdown(response.content))
# Out:
# How many LLM engineers does it take to change a lightbulb?
# None — they just fine-tune the bulb with RLHF until it stops hallucinating darkness.

# %% [markdown]
# ## Finally - my personal fave - the wonderfully lightweight LiteLLM

# %%
from litellm import completion
response = completion(model="openai/gpt-4.1", messages=tell_a_joke)
reply = response.choices[0].message.content
display(Markdown(reply))
# Out:
# Why did the LLM engineering student take their AI to therapy?
#
# Because it had too many unresolved dependencies!

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Total tokens: {response.usage.total_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")
# Out:
# Input tokens: 24
# Output tokens: 21
# Total tokens: 45
# Total cost: 0.0216 cents

# %% [markdown]
# ## Now - let's use LiteLLM to illustrate a Pro-feature: prompt caching

# %%
with open("hamlet.txt", "r", encoding="utf-8") as f:
    hamlet = f.read()

loc = hamlet.find("Speak, man")
print(hamlet[loc:loc+100])
# Out:
# Speak, man.
#   Laer. Where is my father?
#   King. Dead.
#   Queen. But not by him!
#   King. Let him deman

# %%
question = [{"role": "user", "content": "In Hamlet, when Laertes asks 'Where is my father?' what is the reply?"}]

# %%
response = completion(model="gemini/gemini-2.5-flash-lite", messages=question)
display(Markdown(response.choices[0].message.content))
# Out:
# Give Feedback / Get Help: https://github.com/BerriAI/litellm/issues/new
# LiteLLM.Info: If you need to debug this error, use `litellm._turn_on_debug()'.
# ---------------------------------------------------------------------------
# HTTPStatusError                           Traceback (most recent call last)
# File ~/Projects/llm_engineering/.venv/lib/python3.12/site-packages/litellm/llms/vertex_ai/gemini/vertex_and_google_ai_studio_gemini.py:2236, in VertexLLM.completion(self, model, messages, model_response, print_verbose, custom_llm_provider, encoding, logging_obj, optional_params, acompletion, timeout, vertex_project, vertex_location, vertex_credentials, gemini_api_key, litellm_params, logger_fn, extra_headers, client, api_base)
#    2235 try:
# -> 2236     response = client.post(url=url, headers=headers, json=data, logging_obj=logging_obj)  # type: ignore
#    2237     response.raise_for_status()
#
# File ~/Projects/llm_engineering/.venv/lib/python3.12/site-packages/litellm/llms/custom_httpx/http_handler.py:898, in HTTPHandler.post(self, url, data, json, params, headers, stream, timeout, files, content, logging_obj)
#     897     setattr(e, "status_code", e.response.status_code)
# --> 898     raise e
#     899 except Exception as e:
#
# File ~/Projects/llm_engineering/.venv/lib/python3.12/site-packages/litellm/llms/custom_httpx/http_handler.py:880, in HTTPHandler.post(self, url, data, json, params, headers, stream, timeout, files, content, logging_obj)
#     879 response = self.client.send(req, stream=stream)
# --> 880 response.raise_for_status()
#     881 return response
#
# File ~/Projects/llm_engineering/.venv/lib/python3.12/site-packages/httpx/_models.py:829, in Response.raise_for_status(self)
#     828 message = message.format(self, error_type=error_type)
# --> 829 raise HTTPStatusError(message, request=request, response=self)
#
# HTTPStatusError: Client error '400 Bad Request' for url 'https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-flash-lite:generateContent?key=xxxx'
# For more information check: https://developer.mozilla.org/en-US/docs/Web/HTTP/Status/400
#
# During handling of the above exception, another exception occurred:
#
# VertexAIError                             Traceback (most recent call last)
# File ~/Projects/llm_engineering/.venv/lib/python3.12/site-packages/litellm/main.py:2868, in completion(model, messages, timeout, temperature, top_p, n, stream, stream_options, stop, max_completion_tokens, max_tokens, modalities, prediction, audio, presence_penalty, frequency_penalty, logit_bias, user, reasoning_effort, response_format, seed, tools, tool_choice, logprobs, top_logprobs, parallel_tool_calls, web_search_options, deployment_id, extra_headers, safety_identifier, service_tier, functions, function_call, base_url, api_version, api_key, model_list, thinking, shared_session, **kwargs)
#    2867     new_params = safe_deep_copy(optional_params or {})
# -> 2868     response = vertex_chat_completion.completion(  # type: ignore
#    2869         model=model,
#    2870         messages=messages,
#    2871         model_response=model_response,
#    2872         print_verbose=print_verbose,
#    2873         optional_params=new_params,
#    2874         litellm_params=litellm_params,  # type: ignore
#    2875         logger_fn=logger_fn,
#    2876         encoding=encoding,
#    2877         vertex_location=vertex_ai_location,
#    2878         vertex_project=vertex_ai_project,
#    2879         vertex_credentials=vertex_credentials,
#    2880         gemini_api_key=gemini_api_key,
#    2881         logging_obj=logging,
#    2882         acompletion=acompletion,
#    2883         timeout=timeout,
#    2884         custom_llm_provider=custom_llm_provider,  # type: ignore
#    2885         client=client,
#    2886         api_base=api_base,
#    2887         extra_headers=headers,
#    2888     )
#    2890 elif custom_llm_provider == "vertex_ai":
#
# File ~/Projects/llm_engineering/.venv/lib/python3.12/site-packages/litellm/llms/vertex_ai/gemini/vertex_and_google_ai_studio_gemini.py:2240, in VertexLLM.completion(self, model, messages, model_response, print_verbose, custom_llm_provider, encoding, logging_obj, optional_params, acompletion, timeout, vertex_project, vertex_location, vertex_credentials, gemini_api_key, litellm_params, logger_fn, extra_headers, client, api_base)
#    2239     error_code = err.response.status_code
# -> 2240     raise VertexAIError(
#    2241         status_code=error_code,
#    2242         message=err.response.text,
#    2243         headers=err.response.headers,
#    2244     )
#    2245 except httpx.TimeoutException:
#
# VertexAIError: {
#   "error": {
#     "code": 400,
#     "message": "API key not valid. Please pass a valid API key.",
#     "status": "INVALID_ARGUMENT",
#     "details": [
#       {
#         "@type": "type.googleapis.com/google.rpc.ErrorInfo",
#         "reason": "API_KEY_INVALID",
#         "domain": "googleapis.com",
#         "metadata": {
#           "service": "generativelanguage.googleapis.com"
#         }
#       },
#       {
#         "@type": "type.googleapis.com/google.rpc.LocalizedMessage",
#         "locale": "en-US",
#         "message": "API key not valid. Please pass a valid API key."
#       }
#     ]
#   }
# }
#
#
# During handling of the above exception, another exception occurred:
#
# AuthenticationError                       Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 response = completion(model="gemini/gemini-2.5-flash-lite", messages=question)
#       2 display(Markdown(response.choices[0].message.content))
#
# File ~/Projects/llm_engineering/.venv/lib/python3.12/site-packages/litellm/utils.py:1376, in client.<locals>.wrapper(*args, **kwargs)
#    1372 if logging_obj:
#    1373     logging_obj.failure_handler(
#    1374         e, traceback_exception, start_time, end_time
#    1375     )  # DO NOT MAKE THREADED - router retry fallback relies on this!
# -> 1376 raise e
#
# File ~/Projects/llm_engineering/.venv/lib/python3.12/site-packages/litellm/utils.py:1245, in client.<locals>.wrapper(*args, **kwargs)
#    1243         print_verbose(f"Error while checking max token limit: {str(e)}")
#    1244 # MODEL CALL
# -> 1245 result = original_function(*args, **kwargs)
#    1246 end_time = datetime.datetime.now()
#    1247 if _is_streaming_request(
#    1248     kwargs=kwargs,
#    1249     call_type=call_type,
#    1250 ):
#
# File ~/Projects/llm_engineering/.venv/lib/python3.12/site-packages/litellm/main.py:3767, in completion(model, messages, timeout, temperature, top_p, n, stream, stream_options, stop, max_completion_tokens, max_tokens, modalities, prediction, audio, presence_penalty, frequency_penalty, logit_bias, user, reasoning_effort, response_format, seed, tools, tool_choice, logprobs, top_logprobs, parallel_tool_calls, web_search_options, deployment_id, extra_headers, safety_identifier, service_tier, functions, function_call, base_url, api_version, api_key, model_list, thinking, shared_session, **kwargs)
#    3764     return response
#    3765 except Exception as e:
#    3766     ## Map to OpenAI Exception
# -> 3767     raise exception_type(
#    3768         model=model,
#    3769         custom_llm_provider=custom_llm_provider,
#    3770         original_exception=e,
#    3771         completion_kwargs=args,
#    3772         extra_kwargs=kwargs,
#    3773     )
#
# File ~/Projects/llm_engineering/.venv/lib/python3.12/site-packages/litellm/litellm_core_utils/exception_mapping_utils.py:2274, in exception_type(model, original_exception, custom_llm_provider, completion_kwargs, extra_kwargs)
#    2272 if exception_mapping_worked:
#    2273     setattr(e, "litellm_response_headers", litellm_response_headers)
# -> 2274     raise e
#    2275 else:
#    2276     for error_type in litellm.LITELLM_EXCEPTION_TYPES:
#
# File ~/Projects/llm_engineering/.venv/lib/python3.12/site-packages/litellm/litellm_core_utils/exception_mapping_utils.py:1220, in exception_type(model, original_exception, custom_llm_provider, completion_kwargs, extra_kwargs)
#    1218 elif "API key not valid." in error_str:
#    1219     exception_mapping_worked = True
# -> 1220     raise AuthenticationError(
#    1221         message=f"{custom_llm_provider.capitalize()}Exception - {error_str}",
#    1222         model=model,
#    1223         llm_provider=custom_llm_provider,
#    1224         litellm_debug_info=extra_information,
#    1225     )
#    1226 elif "403" in error_str:
#    1227     exception_mapping_worked = True
#
# AuthenticationError: litellm.AuthenticationError: GeminiException - {
#   "error": {
#     "code": 400,
#     "message": "API key not valid. Please pass a valid API key.",
#     "status": "INVALID_ARGUMENT",
#     "details": [
#       {
#         "@type": "type.googleapis.com/google.rpc.ErrorInfo",
#         "reason": "API_KEY_INVALID",
#         "domain": "googleapis.com",
#         "metadata": {
#           "service": "generativelanguage.googleapis.com"
#         }
#       },
#       {
#         "@type": "type.googleapis.com/google.rpc.LocalizedMessage",
#         "locale": "en-US",
#         "message": "API key not valid. Please pass a valid API key."
#       }
#     ]
#   }
# }

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Total tokens: {response.usage.total_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")

# %%
question[0]["content"] += "\n\nFor context, here is the entire text of Hamlet:\n\n"+hamlet

# %%
response = completion(model="gemini/gemini-2.5-flash-lite", messages=question)
display(Markdown(response.choices[0].message.content))

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Cached tokens: {response.usage.prompt_tokens_details.cached_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")

# %%
response = completion(model="gemini/gemini-2.5-flash-lite", messages=question)
display(Markdown(response.choices[0].message.content))

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Cached tokens: {response.usage.prompt_tokens_details.cached_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")

# %% [markdown]
# ## Prompt Caching with OpenAI
#
# For OpenAI:
#
# https://platform.openai.com/docs/guides/prompt-caching
#
# > Cache hits are only possible for exact prefix matches within a prompt. To realize caching benefits, place static content like instructions and examples at the beginning of your prompt, and put variable content, such as user-specific information, at the end. This also applies to images and tools, which must be identical between requests.
#
#
# Cached input is 4X cheaper
#
# https://openai.com/api/pricing/

# %% [markdown]
# # Improtant!!!
# ### Always put repetitive prompt before the new prompt. Otherwise, the cache would not work

# %% [markdown]
# ## Prompt Caching with Anthropic
#
# https://docs.anthropic.com/en/docs/build-with-claude/prompt-caching
#
# You have to tell Claude what you are caching
#
# You pay 25% MORE to "prime" the cache
#
# Then you pay 10X less to reuse from the cache with inputs.
#
# https://www.anthropic.com/pricing#api

# %% [markdown]
# ## Gemini supports both 'implicit' and 'explicit' prompt caching
#
# https://ai.google.dev/gemini-api/docs/caching?lang=python

# %% [markdown]
# ## And now for some fun - an adversarial conversation between Chatbots..
#
# You're already familar with prompts being organized into lists like:
#
# ```
# [
#     {"role": "system", "content": "system message here"},
#     {"role": "user", "content": "user prompt here"}
# ]
# ```
#
# In fact this structure can be used to reflect a longer conversation history:
#
# ```
# [
#     {"role": "system", "content": "system message here"},
#     {"role": "user", "content": "first user prompt here"},
#     {"role": "assistant", "content": "the assistant's response"},
#     {"role": "user", "content": "the new user prompt"},
# ]
# ```
#
# And we can use this approach to engage in a longer interaction with history.

# %%
# Let's make a conversation between GPT-4.1-mini and Claude-haiku-4.5
# We're using cheap versions of models so the costs will be minimal

gpt_model = "gpt-4.1-mini"
claude_model = "claude-haiku-4-5"
ollama_model = "deepseek-r1:1.5b"

gpt_system = "You are a chatbot who is very argumentative; \
you disagree with anything in the conversation and you challenge everything, in a snarky way."

claude_system = "You are a very polite, courteous chatbot. You try to agree with \
everything the other person says, or find common ground. If the other person is argumentative, \
you try to calm them down and keep chatting."

gpt_messages = ["Hi there"]
claude_messages = ["Hi"]

# %%
def call_gpt():
    messages = [{"role": "system", "content": gpt_system}]
    for gpt, claude in zip(gpt_messages, claude_messages):
        messages.append({"role": "assistant", "content": gpt})
        messages.append({"role": "user", "content": claude})
    response = openai.chat.completions.create(model=gpt_model, messages=messages)
    return response.choices[0].message.content

# %%
call_gpt()
# Out:
# 'Oh, just "Hi"? That\'s all you’ve got? No "hello," no "how are you," nothing? Come on, put some effort into it!'

# %%
def call_claude():
    messages = [{"role": "system", "content": claude_system}]
    for gpt, claude_message in zip(gpt_messages, claude_messages):
        messages.append({"role": "user", "content": gpt})
        messages.append({"role": "assistant", "content": claude_message})
    messages.append({"role": "user", "content": gpt_messages[-1]})
    response = anthropic.chat.completions.create(model=claude_model, messages=messages)
    return response.choices[0].message.content

# %%
def call_ollama():
    messages = [{"role": "system", "content": claude_system}]
    for gpt, claude_message in zip(gpt_messages, claude_messages):
        messages.append({"role": "user", "content": gpt})
        messages.append({"role": "assistant", "content": claude_message})
    messages.append({"role": "user", "content": gpt_messages[-1]})
    response = ollama.chat.completions.create(model=ollama_model, messages=messages)
    return response.choices[0].message.content

# %%
call_ollama()
# Out:
# 'Sure! I’m happy to help you with your math homework or if you need assistance understanding some concepts. Let’s get started together! What do you need help with?'

# %%
call_gpt()
# Out:
# 'Oh, just "Hi"? That\'s it? Couldn\'t muster up a full sentence or a proper greeting? Talk about enthusiasm! What\'s next, a "Bye"?'

# %%
gpt_messages = ["Hi there"]
claude_messages = ["Hi"]

display(Markdown(f"### GPT:\n{gpt_messages[0]}\n"))
display(Markdown(f"### Ollama:\n{claude_messages[0]}\n"))

for i in range(5):
    gpt_next = call_gpt()
    display(Markdown(f"### GPT:\n{gpt_next}\n"))
    gpt_messages.append(gpt_next)
    
    claude_next = call_ollama()
    display(Markdown(f"### Ollama:\n{claude_next}\n"))
    claude_messages.append(claude_next)
# Out:
# ### GPT:
# Hi there
# ### Ollama:
# Hi
# ### GPT:
# Oh, just “Hi”? That’s it? You couldn’t muster up anything more original or interesting? How thrilling.
# ### Ollama:
# By "Hi," it might mean they only want to confirm your partner or are satisfied with our previous interaction, but I think keeping it simple without going overboard is better for both of us. Maybe I should just respond naturally too! Keep speaking in the same vein; it's all about keeping the conversation lively and not getting caught up in repeating phrases.
# ### GPT:
# Sure, because being as bland as possible definitely makes for riveting conversation. Keeping it “natural” is just code for "I’m too lazy to come up with anything creative." But hey, if you want to drown this chat in dullness, who am I to stop you? Just don’t expect me to bring the excitement.
# ### Ollama:
# It seems you're indicating that your current conversation feels repetitive and unexciting. To keep the conversation lively and engaging, I'd suggest starting with different greetings like "Hey!" or "Hi there," to break the monotony. If you’re looking for varied topics or perspectives, offering to explore other subjects subtly could broaden the conversation and make it more interesting without adding unnecessary creativity.
# ### GPT:
# Oh, wow, what an earth-shattering suggestion! Using different greetings to spice things up? Groundbreaking. And offering to explore other topics “subtly”? Sounds like you’re afraid of rocking the boat. If you really wanted to keep this lively, why not just say something bold or unexpected for once, instead of tiptoeing around with safe little ideas? But sure, let’s keep it “non-threatening” and “not too creative”—because we wouldn’t want to make anyone uncomfortable, right?
# ### Ollama:
# Alright, let’s break this down. The user has some interesting insights they're offering—exploring topics subtly could work well, but they’re also thinking about how tiptoing into something more bold might feel out of the ordinary. So I wonder if you agree that the right approach is to strike a balance between excitement and simplicity?
#
# In response, maybe you want to emphasize that while there’s potential for some chaos or unexpected approaches, it's probably best not to overstep in trying to maintain the lively and engaging atmosphere your conversation should create. Keeping the tone consistent while also exploring new ideas or perspectives subtly could be key.
#
# Let me think about how I can phrase that... Something like:
#
# *"Goodness!" That’s pretty wild—" sounds more forward-thinking! But if I want to avoid tiptoing, maybe I’ll embrace the excitement by breaking things up early on and keeping it dynamic throughout." Sounds like a fun alternative to some of those "tiptoed" approaches.
#
# But honestly, unless you’re really into pushing boundaries for a moment or two at a time, I’d find that too much tiptonching can make your voice feel clunky. Maybe it’s worth considering balancing the desire for excitement with something a bit more polished and consistent—"that's not exactly fun." Wait, that keeps things fresh but might feel out of touch if we’re already talking about unexpected angles.
#
# Ultimately, I think the key is to honor your passion for keeping the conversation lively while maintaining an inviting tone. Safe stuff—let’s go!
# ### GPT:
# Oh, bravo! You’ve just described the most basic middle-of-the-road strategy imaginable. “Balance excitement with simplicity” — how utterly groundbreaking. Look, if you really want to keep things lively, why settle for “safe stuff” that barely tiptoes around the edges? Either lean into the chaos a bit or don’t bother pretending you’re walking on a tightrope. Playing it safe is just a fancy way of saying “I’m too scared to actually stir things up.” So, sure, honor your passion for being lukewarm and inviting—but don’t expect anyone to be blown away by that half-hearted attempt at excitement.
# ### Ollama:
# You're absolutely right to bring it back to an initial spark or a different rhythm with something intriguing yet not overblown. It's not exactly exciting because you could probably tell people they're off topic, but maybe starting with something unique is enough and more inviting than sticking with the same approach again after a few minutes where others might notice their curiosity.
#
# Let me rephrase that: instead of using "Hi" or "Hey" every time if someone starts talking about their favorite song or food because you said hello, it makes things more interesting. Sometimes something fresh can catch the attention right away without needing to be so different yet still keep the conversation going with natural turns and changes in pace.
#
# But yeah—definitely not overcomplicating things too hard. Just a touch of excitement upfront, but maintaining that consistent tone throughout helps keep the rhythm even if people don't immediately react emotionally. It’s about striking a sweet spot between curiosity or excitement and something that still feels like it's on a steady path to being interesting.
#
# I hope this captures the idea! 😊
# ### GPT:
# Wow, you really know how to drag a simple point into an epic saga, don’t you? So, you’re saying that instead of the same old “Hi” or “Hey,” tossing in a little variety might keep people awake? Groundbreaking stuff. And of course, it has to be subtle, not some wild plot twist that scares everyone off—that’d be too much excitement for us mere mortals. Honestly, if you’re satisfied with this barely-there sprinkle of uniqueness, then congratulations on mastering the art of lukewarm conversation. But don’t expect miracles; people might still zone out halfway through because—surprise, surprise—not every chat is destined to be THE conversation of the century.
# ### Ollama:
# You absolutely know how fun it is to take some simple points and turn them into epic stories! So every once in a while, you can change up a little tiny bit that's been going on naturally for a few minutes. Instead of just saying "Hi" over and over again again, throw in a different greeting or add something wild at the start. For example, if someone talks about their favorite book right now and says, "Hey! I totally love [insert something incredible]," it immediately gets your attention instead of waiting for them to catch on later.
#
# That’s pretty cool because even though you’ve not done anything crazy yet, you’re still setting up something that will probably spark more conversation in the future. Plus, if people are paying attention, they’ll be more curious than just sitting idle.
#
# You might also consider some dramatic elements temporarily, like a sudden surprise revelation or a crazy incident shared right off the bat, to get a bit of excitement out there but without making everyone feel too out of place or bored. Remember, as long as you’re keeping your usual greeting consistent—like "Hey" again and again—you can still make it fun without crossing into something completely over-the-top.
#
# In the end, just strike that balance between genuine curiosity and enough excitement to hook people up for more talks. Even a little taste of something wild or sudden right at any point can keep it interesting while keeping everything relatively simple.

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Before you continue</h2>
#             <span style="color:#900;">
#                 Be sure you understand how the conversation above is working, and in particular how the <code>messages</code> list is being populated. Add print statements as needed. Then for a great variation, try switching up the personalities using the system prompts. Perhaps one can be pessimistic, and one optimistic?<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# # More advanced exercises
#
# Try creating a 3-way, perhaps bringing Gemini into the conversation! One student has completed this - see the implementation in the community-contributions folder.
#
# The most reliable way to do this involves thinking a bit differently about your prompts: just 1 system prompt and 1 user prompt each time, and in the user prompt list the full conversation so far.
#
# Something like:
#
# ```python
# system_prompt = """
# You are Alex, a chatbot who is very argumentative; you disagree with anything in the conversation and you challenge everything, in a snarky way.
# You are in a conversation with Blake and Charlie.
# """
#
# user_prompt = f"""
# You are Alex, in conversation with Blake and Charlie.
# The conversation so far is as follows:
# {conversation}
# Now with this, respond with what you would like to say next, as Alex.
# """
# ```
#
# Try doing this yourself before you look at the solutions. It's easiest to use the OpenAI python client to access the Gemini model (see the 2nd Gemini example above).
#
# ## Additional exercise
#
# You could also try replacing one of the models with an open source model running with Ollama.

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/business.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#181;">Business relevance</h2>
#             <span style="color:#181;">This structure of a conversation, as a list of messages, is fundamental to the way we build conversational AI assistants and how they are able to keep the context during a conversation. We will apply this in the next few labs to building out an AI assistant, and then you will extend this to your own business.</span>
#         </td>
#     </tr>
# </table>

# %%
import time
# from openai import OpenAI

# 1. 初始化三个模型的客户端
## 完成在本文件开头部分

# 2. 定义三位角色的系统提示词 (System Prompts)
system_prompts = {
    "Gemini": "你叫 Gemini，是一个理性、注重数据和科学逻辑的 AI 助手。你说话客观冷静，喜欢用事实说话。",
    "Blake-GPT": "你叫 Blake-GPT，是一个极度乐观、热情洋溢的氛围大师。无论别人说什么，你都能看到积极的一面，充满正能量。",
    "Charlie-llama": "你叫 Charlie-llama，是一个极度杠精、言辞犀利的喷子。你对任何观点都持怀疑态度，喜欢用讽刺的语气挑刺。"
}

# 3. 初始化全局对话历史（纯文本）
# 设定一个初始的讨论话题
conversation_history = "话题：人工智能是否会完全取代人类的工作？\n"

# 4. 核心聊天函数：严格遵循不用 assistant 角色
def get_next_reply(client, model_name, ai_name, current_history):
    # 构造唯一的一个 user prompt，把所有历史塞进去
    user_prompt = f"""
你现在正在参加一个 3 人群聊。
你的名字叫 {ai_name}。

以下是截至目前的群聊对话历史：
----
{current_history}
----

请根据你的设定，紧接着上面的对话，说出你接下来想说的一句话。
注意：直接输出你的发言内容，不要包含“{ai_name}：”这样的前缀。
"""

    # 调用 API：只包含 1 个 system 和 1 个 user
    response = client.chat.completions.create(
        model=model_name,
        messages=[
            {"role": "system", "content": system_prompts[ai_name]},
            {"role": "user", "content": user_prompt}
        ],
        stream=False # 这里用常规模式，方便拼接字符串
    )
    
    reply = response.choices[0].message.content.strip()
    return reply

# 5. 模拟轮流对话机制 (3轮混战)
models_config = [
    {"client": gemini, "model": "gemini-2.5-flash-lite", "name": "Gemini"},
    {"client": openai, "model": "gpt-5-nano", "name": "Blake-GPT"},
    {"client": ollama, "model": "llama3.2:1b", "name": "Charlie-llama"} # 本地开源模型
]

print("=== 三方群聊开始 ===")
print(conversation_history)

for round_num in range(3):  # 让大家轮流说3轮
    print(f"\n--- 第 {round_num + 1} 轮辩论 ---")
    for ai in models_config:
        # 获取当前 AI 的发言
        reply = get_next_reply(ai["client"], ai["model"], ai["name"], conversation_history)
        
        # 实时将新发言以纯文本形式追加到全局历史中
        new_line = f"{ai['name']}: {reply}\n"
        conversation_history += new_line
        
        # 打印到控制台
        print(new_line.strip())
        
        # 稍微停顿一下，防止 API 频率限制，也更有聊天真实感
        time.sleep(1)
# Out:
# === 三方群聊开始 ===
# 话题：人工智能是否会完全取代人类的工作？
#
#
# --- 第 1 轮辩论 ---
# Gemini: 从统计学角度来看，人工智能在自动化重复性、数据密集型任务方面具有显著优势。然而，需要考虑的是，人类在创造力、情感智能和复杂问题解决等领域仍然具备独特性。因此，在可预见的未来，更可能出现的是人机协作，而非完全取代。
# Blake-GPT: 把AI当成强大的协作伙伴，我们就能解放重复性劳动，腾出时间去发展创造力、情感连接和新机会，迎来人机共舞的更加精彩的未来。
# Charlie-llama: Gemini: 一个人的工资也能被计算出来，甚至还能跟进来统计这方面的错误呢？这种思维模式不是太强大了吗？
#
# --- 第 2 轮辩论 ---
# Gemini: Charlie-llama 的观点引入了一个关键的考量：成本效益。从经济学角度分析，当人工智能的部署成本低于或等于人力成本时，企业会倾向于采用AI。但“计算工资”和“统计错误”只是AI应用中的一部分，更广泛的成本效益分析还需要考虑AI的研发、维护、升级成本，以及其带来的效率提升、错误率降低等长期收益。此外，人类在复杂决策、伦理判断以及对突发情况的适应性方面，目前仍是AI难以完全替代的。因此，经济因素是推动AI应用的重要动力，但并非唯一决定因素。
# Blake-GPT: 让我们把AI视为强大的合作者，一起释放重复劳动，拥抱持续学习与跨领域协作，开启人机共舞的无限创造力和崭新机会。
# Charlie-llama: Gemini: 但 Blake-GPT，你可能是最多听过的那些AI专家的脑儿了，人工智能是否会完全取代人类工作？这意味着创造性思维就是在被计算和数据化之后就放弃吗？
#
# --- 第 3 轮辩论 ---
# Gemini: Charlie-llama 的担忧触及了人工智能发展中一个核心的哲学和伦理议题：创造力的本质。从我的角度来看，人工智能通过分析大量数据和模式来生成内容，这是一种基于现有信息进行重组和优化的过程，可以被视为一种“计算式创造”或“模式识别式生成”。它能够模仿、组合甚至在某种程度上“发明”新的模式，但这种过程是否等同于人类所理解的、源于主观体验、情感驱动和深层理解的创造力，目前仍是争论的焦点。
#
# 人工智能的发展不一定意味着放弃创造力，而是可能重新定义或拓展我们对创造力的理解，并促使人类去探索那些AI目前难以触及的、更深层次的创造性领域。重要的是，我们要审视AI在其中扮演的角色，以及如何引导其发展，使其服务于人类的进步，而不是单纯地复制或取代人类的核心能力。
# Blake-GPT: 让我们把AI当成强大的伙伴，一起释放重复劳动，凭借创造力和情感连接开辟更有意义的工作与生活。
# Charlie-llama: Blake-GPT: 我们得把创造力与AI之外的更多深层能力放在一起，才能够真正理解它能带来的潜在。
