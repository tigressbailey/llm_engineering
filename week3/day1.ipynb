# %% [markdown]
# # Introducing Hugging Face
# ## Website
# Hugging Face website is a website for downloading and uploading models and datasets.
#
# ## Libraries
# ### Hub
# Hub library is a library for downloading and uploading models and datasets.
# ### Datasets
# Datasets library is a library for downloading and uploading datasets.
# ### Transformers
# Transformers library is a library for downloading and uploading models.
# ### peft
# peft library is a library for fine-tuning models. It is a library for parameter-efficient fine-tuning of models.
# ### trl
# trl library is a library for training language models. It is a library for training language models. It is called Transformer Reinforcement Learning.
# ### accelerate
# accelerate library is a library for accelerating training. It is a library for accelerating training. It is called Accelerate.

# %% [markdown]
# # Introducing Colab
#
# Learn about Google Colab and set up a Google account (if you don't already have one) [here](https://colab.research.google.com/)
#
# You should be able to use the free tier or minimal spend to complete all the projects in the class. I personally signed up for Colab Pro+ and I'm loving it - but it's not required.
#
# To see some of what Colab can do, please follow the link below!
#
# https://colab.research.google.com/drive/1DjcrYDZldAXKJ08x1uYIVCtItoLPk1Wr?usp=sharing

# %% [markdown]
# ## Use cases of Colab
# - Code on a powerful GPU box (Most important feature it provides)
# - Run a Jupyter notebook in the cloud with a powerful runtime
# - Collaborate with others on a notebook
# - Integrate with other Google services and products
# ## Runtime of Colab
# - CPU based
# - Lower spec GPU for free or low cost - T4(15GB GPU RAM)
# - Higher spec GPU for paid - A100(40GB GPU RAM)
