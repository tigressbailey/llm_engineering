# %% [markdown]
# # Navigate the most useful 5 leaderboards
# - [Artifical Analysis leaderboard](https://artificialanalysis.ai/)
# - [Vellum: includes API cost and context window](https://www.vellum.ai/llm-leaderboard)
# - [Scale.com: SEAL leaderboards](https://labs.scale.com/leaderboard)
# - [Hugging Face: Open Source leaderboards](https://huggingface.co/spaces/open-llm-leaderboard/open_llm_leaderboard)
# - [Live Bench: Contamination-free leaderboard](https://live-bench.ai/)

# %% [markdown]
# ## The purpose of Arenas
# - Compare frontier and open-source models
# - Blind human evals based on head-to-head comparison
# - LLMs are mensured with an ELO-syule score rating
#
# ## The LM Arena
# URL: [lmarena.ai](https://lmarena.ai/)
# - 100+ models
# - 1000+ leaderboard
# - 10000+ leaderboard

# %% [markdown]
# ## Commercial Use cases
# - ChatGPT Wrapper: Duolingo, copilots
# - Specialized: Harvey(LLM to Law), nebula.io(LLM to hiring), saleforce Health, Khanmigo, Palantir(data platform)
# - Agentic AI: Claude code, OpenAI codex, OpenAI Agent
